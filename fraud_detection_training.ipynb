# %% [markdown]
# <a href="https://colab.research.google.com/github/princetech89/Real-time-Credit-Card-Fraud-Detection/blob/main/fraud_detection_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/default of credit card clients(Data).csv")

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %% [markdown]
# Renaming Target Column

# %%
df.rename(columns={'default payment next month':'default'}, inplace=True)

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# 0         0         0         0        1
# ...

# %% [markdown]
# Drop id columns it didnt help to Predicite future insights.

# %%
df.drop(columns=['ID'],inplace=True)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %% [markdown]
# Fixing Categorical columns sex,Eduction,Marriage

# %%
# Fix invalid categories
df['EDUCATION'] = df['EDUCATION'].replace([0, 5, 6], 4)   # Others
df['MARRIAGE'] = df['MARRIAGE'].replace(0, 3)            # Others

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %% [markdown]
# Fix Categorical Columns

# %%
# Fix invalid categories
df['EDUCATION'] = df['EDUCATION'].replace([0, 5, 6], 4)   # Others
df['MARRIAGE'] = df['MARRIAGE'].replace(0, 3)            # Others

# Convert to categorical
cat_cols = ['SEX', 'EDUCATION', 'MARRIAGE']
df[cat_cols] = df[cat_cols].astype('category')

# %%
df.head()
# Out:
#    LIMIT_BAL SEX EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0      20000   2         2        1   24      2      2     -1     -1     -2
# 1     120000   2         2        2   26     -1      2      0      0      0
# 2      90000   2         2        2   34      0      0      0      0      0
# 3      50000   2         2        1   37      0      0      0      0      0
# 4      50000   1         2        1   57     -1      0     -1      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# 0         0         0         0        1
# ...

# %% [markdown]
# Scale Financial Amount Features

# %%
from sklearn.preprocessing import StandardScaler

amount_cols = [col for col in df.columns if 'AMT' in col or col == 'LIMIT_BAL']

scaler = StandardScaler()
df[amount_cols] = scaler.fit_transform(df[amount_cols])

# %%
df.head()
# Out:
#    LIMIT_BAL SEX EDUCATION MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0  -1.136720   2         2        1   24      2      2     -1     -1     -2
# 1  -0.365981   2         2        2   26     -1      2      0      0      0
# 2  -0.597202   2         2        2   34      0      0      0      0      0
# 3  -0.905498   2         2        1   37      0      0      0      0      0
# 4  -0.905498   1         2        1   57     -1      0     -1      0      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...  -0.672497  -0.663059  -0.652724 -0.341942 -0.227086 -0.296801
# 1  ...  -0.621636  -0.606229  -0.597966 -0.341942 -0.213588 -0.240005
# 2  ...  -0.449730  -0.417188  -0.391630 -0.250292 -0.191887 -0.240005
# 3  ...  -0.232373  -0.186729  -0.156579 -0.221191 -0.169361 -0.228645
# 4  ...  -0.346997  -0.348137  -0.331482 -0.221191  1.335034  0.271165
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# 0 -0.308063 -0.314136 -0.293382        1
# ...

# %% [markdown]
# EDA AFTER CLEANING (CLASS-WISE BEHAVIOR)

# %%
df['default'].value_counts(normalize=True)
# Out:
# default
# 0    0.7788
# 1    0.2212
# Name: proportion, dtype: float64

# %% [markdown]
# Visualize Class Imbalance

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x='default', data=df)
plt.title("Default vs Non-Default")
plt.show()

# %% [markdown]
# Credit Limit vs Default

# %%
sns.boxplot(x='default', y='LIMIT_BAL', data=df)
plt.title("Credit Limit vs Default")
plt.show()

# %% [markdown]
# Repayment Behavior

# %%
sns.boxplot(x='default', y='PAY_0', data=df)
plt.title("Recent Payment Status vs Default")
plt.show()

# %% [markdown]
# MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split

X = df.drop('default', axis=1)
y = df['default']

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(
    class_weight='balanced',
    max_iter=1000
)

lr.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %% [markdown]
# Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=200,
    class_weight='balanced',
    random_state=42
)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=200,
#                        random_state=42)

# %% [markdown]
# MODEL EVALUATION

# %%
y_pred_lr = lr.predict(X_test)
y_prob_lr = lr.predict_proba(X_test)[:, 1]

y_pred_rf = rf.predict(X_test)
y_prob_rf = rf.predict_proba(X_test)[:, 1]

# %% [markdown]
# Recall, Precision, F1

# %%
from sklearn.metrics import classification_report

print("Logistic Regression\n")
print(classification_report(y_test, y_pred_lr))

print("Random Forest\n")
print(classification_report(y_test, y_pred_rf))
# Out:
# Logistic Regression
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.70      0.77      4673
#            1       0.37      0.62      0.46      1327
#
#     accuracy                           0.68      6000
#    macro avg       0.62      0.66      0.62      6000
# weighted avg       0.76      0.68      0.70      6000
#
# Random Forest
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4673
#            1       0.64      0.34      0.45      1327
#
#     accuracy                           0.81      6000
#    macro avg       0.74      0.64      0.67      6000
# weighted avg       0.79      0.81      0.79      6000

# %% [markdown]
# ROC-AUC

# %%
from sklearn.metrics import roc_auc_score

print("LR ROC-AUC:", roc_auc_score(y_test, y_prob_lr))
print("RF ROC-AUC:", roc_auc_score(y_test, y_prob_rf))
# Out:
# LR ROC-AUC: 0.7083915020485978
# RF ROC-AUC: 0.7613953299357482

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix

sns.heatmap(confusion_matrix(y_test, y_pred_rf),
            annot=True, fmt='d', cmap='Blues')
plt.title("Random Forest Confusion Matrix")
plt.show()
